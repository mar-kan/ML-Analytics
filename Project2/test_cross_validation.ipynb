# %% [markdown]
# # Machine Learning and Analytics

# %% [markdown]
# ## Homework Project 2

# %% [markdown]
# ### Cross-validation tests

# %%
from polynomial_regression_CV import *

# %%
beta = np.array([[10, -140, 400, -250]]).T
n = 10000
sig = 5
u, y = generate_data_even(3, beta , sig, n, 0)

# %%
ps = [1, 3, 15]
K_vals = [10, 100, 500, 1000, 10000]
X = {}
cv = {}

# %%
for p in ps:
    X[p] = model_matrix(p, u)
    cv[p] = {}
    for K in K_vals:
        cv[p][K] = linear_cv(K,  n, X[p], y)
        print(f"p={p}, K={K}, CV Error: {cv[p][K]:.4f}")
# Out:
# p=1, K=10, CV Error: 0.0050
# p=1, K=100, CV Error: 0.0050
# p=1, K=500, CV Error: 0.0050
# p=1, K=1000, CV Error: 0.0050
# p=1, K=10000, CV Error: 0.0050
# p=3, K=10, CV Error: 0.0025
# p=3, K=100, CV Error: 0.0025
# p=3, K=500, CV Error: 0.0025
# p=3, K=1000, CV Error: 0.0025
# p=3, K=10000, CV Error: 0.0025
# p=15, K=10, CV Error: 0.0025
# p=15, K=100, CV Error: 0.0025
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# Cell In[84], line 5
#       3 cv[p] = {}
#       4 for K in K_vals:
# ----> 5     cv[p][K] = linear_cv(K,  n, X[p], y)
#       6     print(f"p={p}, K={K}, CV Error: {cv[p][K]:.4f}")
#
# File c:\Users\Marianna\OneDrive - KANELLAKIS, G., & CO. O.E\Marianna\G-UDS\ML-Analytics\Project2\polynomial_regression_CV.py:15, in linear_cv(K, n, X, y)
#      12 X_test, y_test = X[test_ind, :], y[test_ind]
#      14 # fit model and evaluate test loss
# ---> 15 betahat = train(X_train,y_train)
#      16 loss.append(test_coefficients(n, betahat, X_test, y_test))
#      17 cv = sum(loss) / n
#
# File c:\Users\Marianna\OneDrive - KANELLAKIS, G., & CO. O.E\Marianna\G-UDS\ML-Analytics\Project2\polynomial_regression.py:86, in train(X, y)
#      73 def train(X, y):
#      74    """
#      75     Solves the equation: (X^T * X) * beta = X^T * y
#      76     to find the coefficients that minimize the loss (squared error)
#    (...)     83         - betahat (nparray): Estimated coefficients vector [p+1, 1]
#      84     """
# ---> 86    betahat = solve(X.T @ X, X.T @ y)
#      87    return betahat
#
# File c:\Users\Marianna\OneDrive - KANELLAKIS, G., & CO. O.E\Marianna\G-UDS\ML-Analytics\Project2\.venv\Lib\site-packages\numpy\linalg\_linalg.py:452, in solve(a, b)
#     449 signature = 'DD->D' if isComplexType(t) else 'dd->d'
#     450 with errstate(call=_raise_linalgerror_singular, invalid='call',
#     451               over='ignore', divide='ignore', under='ignore'):
# --> 452     r = gufunc(a, b, signature=signature)
#     454 return wrap(r.astype(result_t, copy=False))
#
# File c:\Users\Marianna\OneDrive - KANELLAKIS, G., & CO. O.E\Marianna\G-UDS\ML-Analytics\Project2\.venv\Lib\site-packages\numpy\linalg\_linalg.py:145, in _raise_linalgerror_singular(err, flag)
#     144 def _raise_linalgerror_singular(err, flag):
# --> 145     raise LinAlgError("Singular matrix")
#
# LinAlgError: Singular matrix
